# %% [markdown]
# # Milestone Project 1: Tic Tac Toe
#
# Your assignment: Create a Tic Tac Toe game. You are free to use any IDE you like.
#
# Here are the requirements:
#
# * 2 players should be able to play the game (both sitting at the same computer)
# * The board should be printed out every time a player makes a move
# * You should be able to accept input of the player position and then place a symbol on the board

# %%
xo= ['#','X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']
xo
# Out:
# ['#', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']

# %%
br=['#', '-', '-', '-']
br
# Out:
# ['#', '-', '-', '-']

# %%
def print_board():
    
    print( ' | ' + xo[7] + ' | ' + xo[8] + ' | ' + xo[9] + ' | ' )
    print( ' | ' + br[1] + ' | ' + br[2] + ' | ' + br[3] + ' | ' )
    print( ' | ' + xo[4] + ' | ' + xo[5] + ' | ' + xo[6] + ' | ' )
    print( ' | ' + br[1] + ' | ' + br[2] + ' | ' + br[3] + ' | ' )
    print( ' | ' + xo[1] + ' | ' + xo[2] + ' | ' + xo[3] + ' | ' )

# %%
xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '

# %%
print_board()
# Out:
#  |   |   |   |
#  | - | - | - |
#  |   |   |   |
#  | - | - | - |
#  |   |   |   |

# %%
xo= ['#','X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']
xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '

br=['#', '-', '-', '-']

def print_board():
    
    print( ' | ' + xo[7] + ' | ' + xo[8] + ' | ' + xo[9] + ' | ' )
    print( ' | ' + br[1] + ' | ' + br[2] + ' | ' + br[3] + ' | ' )
    print( ' | ' + xo[4] + ' | ' + xo[5] + ' | ' + xo[6] + ' | ' )
    print( ' | ' + br[1] + ' | ' + br[2] + ' | ' + br[3] + ' | ' )
    print( ' | ' + xo[1] + ' | ' + xo[2] + ' | ' + xo[3] + ' | ' )


choose=True

while choose:
    a=input('Player 1 - Choose X or O: ')
    if a.upper()=='X' or a.upper()=='O':
        choose=False
        
        if a.upper()=='X':
            player1='X'
            player2='O'
            print('\nPlayer 1 is X \nPlayer 2 is O \nLET´S PLAY!')
        else:
            player1='O'
            player2='X'
            print('\nPlayer 1 is O \nPlayer 2 is X \nLET´S PLAY!')
        
    else:
        continue

play=True

while play:
       
    p1=True    
    while p1:
        print('\n')
        b=input('Player1 choose between 1 to 9 to select your playing spot:\n\n | 7 | 8 | 9 |\n | 4 | 5 | 6 |\n | 1 | 2 | 3 |\n\n ')
        
        if b.isdigit():
            c=int(b)
        else:
            continue
    
        if c in range(1,10) and xo[c]==' ':
            p1=False
                     
            xo[c]=player1
        
            print('\n')
            print_board()
               
            if xo[9]==xo[5]==xo[1]==player1 or xo[1]==xo[2]==xo[3]==player1 or xo[4]==xo[5]==xo[6]==player1 or xo[7]==xo[8]==xo[9]==player1 or xo[7]==xo[5]==xo[3]==player1 or xo[7]==xo[4]==xo[1]==player1 or xo[8]==xo[5]==xo[2]==player1 or xo[9]==xo[6]==xo[3]==player1:
                repeat=input('\nPlayer 1 has won! Would you like to play again? Type YES if you wanna play again ')
                if repeat.upper()=='YES':
                    xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '
                    continue
                else:
                    play=False
                
            elif xo[1]!=' ' and  xo[2]!=' ' and xo[3]!=' ' and xo[4]!=' ' and xo[5]!=' ' and xo[6]!=' ' and xo[7]!=' ' and xo[8]!=' ' and xo[9]!=' ': 
                repeat=input('\nIt´s a tie! Would you like to play again? Type YES if you wanna play again ')
                if repeat.upper()=='YES':
                    xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '
                    continue
                else:
                    play=False
              
        else:
            print('That spot is already chosen, please select another one')
            continue
    
       
    
    if play==False:
        break
        
    p2=True
    while p2:
        print('\n')
        b=input('Player2 choose between 1 to 9 to select your playing spot:\n\n | 7 | 8 | 9 |\n | 4 | 5 | 6 |\n | 1 | 2 | 3 |\n\n ')
     
        if b.isdigit():
            c=int(b)
        else:
            continue
    
        if c in range(1,10) and xo[c]==' ':
            p2=False
             
            
            xo[c]=player2
        
            print('\n')
            print_board()
            
            if xo[9]==xo[5]==xo[1]==player2 or xo[1]==xo[2]==xo[3]==player2 or xo[4]==xo[5]==xo[6]==player2 or xo[7]==xo[8]==xo[9]==player2 or xo[7]==xo[5]==xo[3]==player2 or xo[7]==xo[4]==xo[1]==player2 or xo[8]==xo[5]==xo[2]==player2 or xo[9]==xo[6]==xo[3]==player2:
                repeat=input('\nPlayer2 has won! Would you like to play again? Type YES if you wanna play again ')
                if repeat.upper()=='YES':
                    xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '
                    continue
                else:
                    play=False
                
            
            elif xo[1]!=' ' and  xo[2]!=' ' and xo[3]!=' ' and xo[4]!=' ' and xo[5]!=' ' and xo[6]!=' ' and xo[7]!=' ' and xo[8]!=' ' and xo[9]!=' ': 
                repeat=input('\nIt´s a tie! Would you like to play again? Type YES if you wanna play again ')
                if repeat.upper()=='YES':
                    xo[1]=xo[2]=xo[3]=xo[4]=xo[5]=xo[6]=xo[7]=xo[8]=xo[9]=' '
                    continue
                else:
                    play=False
               
        else:
            print('That spot is already chosen, please select another one')
            continue
        
    if play==False:
        break
# Out:
# Player 1 - Choose X or O: x
#
# Player 1 is X
# Player 2 is O
# LET´S PLAY!
#
#
# Player1 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  5
#
#
#  |   |   |   |
#  | - | - | - |
#  |   | X |   |
#  | - | - | - |
#  |   |   |   |
#
#
# Player2 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  2
#
#
#  |   |   |   |
#  | - | - | - |
#  |   | X |   |
#  | - | - | - |
#  |   | O |   |
#
#
# Player1 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  3
#
#
#  |   |   |   |
#  | - | - | - |
#  |   | X |   |
#  | - | - | - |
#  |   | O | X |
#
#
# Player2 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  3
# That spot is already chosen, please select another one
#
#
# Player2 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  6
#
#
#  |   |   |   |
#  | - | - | - |
#  |   | X | O |
#  | - | - | - |
#  |   | O | X |
#
#
# Player1 choose between 1 to 9 to select your playing spot:
#
#  | 7 | 8 | 9 |
#  | 4 | 5 | 6 |
#  | 1 | 2 | 3 |
#
#  7
#
#
#  | X |   |   |
#  | - | - | - |
#  |   | X | O |
#  | - | - | - |
#  |   | O | X |
#
# Player 1 has won! Would you like to play again? Type YES if you wanna play again n
